# %%
# Searching for dataset
# !kaggle datasets list -s gtsrb-german-traffic-sign
# Out:
# ref                                                                title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# meowmeowmeowmeowmeow/gtsrb-german-traffic-sign                     GTSRB - German Traffic Sign Recognition Benchmark  612MB  2018-11-25 18:12:34          59354        837  0.8235294
# valentynsichkar/traffic-signs-preprocessed                         Traffic Signs Preprocessed                           4GB  2019-08-31 18:22:11           8229        227  1.0
# eunjurho/german-traffic-sign-recognition-benchmark-cropped         german_traffic_sign_recognition_benchmark_cropped  206MB  2019-11-10 15:22:13            287          7  0.75
# bhavinmoriya/german-traffic-sign-recognition-benchmark             German Traffic Sign Recognition Benchmark          306MB  2021-12-17 17:03:58             21          3  0.3529412
# valentynsichkar/traffic-signs-1-million-images-for-classification  Traffic Signs 1 million images for Classification   20GB  2021-02-08 16:45:43            226          6  1.0
# valentynsichkar/preprocessed-light-version-of-traffic-signs        Pre-processed Light version of Traffic Signs         8GB  2021-04-10 13:35:24             40          3  1.0
# riyajoshi30/traffic                                                Traffic                                             12KB  2020-10-26 06:36:23              0          0  0.1875

# %%
# Downloading dataset and coming out of directory
# !kaggle datasets download meowmeowmeowmeowmeow/gtsrb-german-traffic-sign
# Out:
# Downloading gtsrb-german-traffic-sign.zip to C:\Users\Sanghyun_Ryu\Machine-Learning-Projects\Traffic_Sign_Classfication
#   0%|          | 0.00/612M [00:00<?, ?B/s]
#   0%|          | 1.00M/612M [00:00<04:36, 2.32MB/s]
#   0%|          | 3.00M/612M [00:00<01:37, 6.54MB/s]
#   1%|1         | 7.00M/612M [00:00<00:42, 14.9MB/s]
#   2%|1         | 10.0M/612M [00:00<00:41, 15.4MB/s]
#   2%|2         | 14.0M/612M [00:00<00:29, 21.1MB/s]
#   3%|2         | 17.0M/612M [00:01<00:33, 18.5MB/s]
#   4%|3         | 22.0M/612M [00:01<00:26, 23.0MB/s]
#   4%|4         | 26.0M/612M [00:01<00:24, 25.6MB/s]
#   5%|4         | 29.0M/612M [00:01<00:26, 23.4MB/s]
#   6%|5         | 35.0M/612M [00:01<00:19, 31.5MB/s]
#   6%|6         | 39.0M/612M [00:01<00:17, 33.4MB/s]
#   7%|7         | 43.0M/612M [00:01<00:16, 35.4MB/s]
#   8%|7         | 47.0M/612M [00:02<00:20, 28.7MB/s]
#   8%|8         | 51.0M/612M [00:02<00:20, 29.0MB/s]
#   9%|8         | 55.0M/612M [00:02<00:19, 30.1MB/s]
#  10%|9         | 59.0M/612M [00:02<00:17, 32.6MB/s]
#  10%|#         | 63.0M/612M [00:02<00:22, 25.4MB/s]
#  11%|#1        | 69.0M/612M [00:02<00:17, 32.9MB/s]
#  12%|#2        | 75.0M/612M [00:03<00:14, 39.0MB/s]
#  13%|#3        | 80.0M/612M [00:03<00:15, 35.0MB/s]
#  75%|#######5  | 459M/612M [00:15<00:04, 34.9MB/s]
#  76%|#######5  | 463M/612M [00:15<00:04, 36.1MB/s]
#  76%|#######6  | 467M/612M [00:15<00:04, 36.8MB/s]
#  77%|#######6  | 471M/612M [00:15<00:05, 29.1MB/s]
#  78%|#######7  | 475M/612M [00:15<00:05, 26.8MB/s]
#  79%|#######8  | 482M/612M [00:15<00:04, 33.5MB/s]
#  79%|#######9  | 486M/612M [00:15<00:04, 30.6MB/s]
#  81%|########  | 493M/612M [00:16<00:03, 37.6MB/s]
#  81%|########1 | 497M/612M [00:16<00:03, 32.9MB/s]
#  82%|########2 | 504M/612M [00:16<00:02, 39.4MB/s]
#  83%|########3 | 509M/612M [00:16<00:02, 39.4MB/s]
#  84%|########3 | 513M/612M [00:16<00:03, 32.3MB/s]
#  84%|########4 | 517M/612M [00:16<00:02, 33.9MB/s]
#  85%|########5 | 521M/612M [00:16<00:02, 34.6MB/s]
#  86%|########5 | 525M/612M [00:17<00:02, 35.3MB/s]
#  86%|########6 | 529M/612M [00:17<00:02, 36.9MB/s]
#  87%|########7 | 533M/612M [00:17<00:02, 31.4MB/s]
#  88%|########8 | 540M/612M [00:17<00:02, 34.0MB/s]
#  89%|########9 | 546M/612M [00:17<00:01, 39.2MB/s]
#  90%|########9 | 550M/612M [00:17<00:01, 39.4MB/s]
#  91%|######### | 554M/612M [00:17<00:01, 34.0MB/s]
#  92%|#########1| 560M/612M [00:18<00:01, 39.8MB/s]
#  92%|#########2| 565M/612M [00:18<00:01, 39.8MB/s]
#  93%|#########2| 569M/612M [00:18<00:01, 33.7MB/s]
#  94%|#########3| 575M/612M [00:18<00:01, 37.5MB/s]
#  95%|#########4| 580M/612M [00:18<00:01, 32.2MB/s]
#  96%|#########5| 587M/612M [00:18<00:00, 40.5MB/s]
#  97%|#########6| 592M/612M [00:18<00:00, 40.6MB/s]
#  98%|#########7| 597M/612M [00:19<00:00, 38.0MB/s]
#  98%|#########8| 601M/612M [00:19<00:00, 38.2MB/s]
#  99%|#########8| 605M/612M [00:19<00:00, 34.7MB/s]
# 100%|#########9| 609M/612M [00:19<00:00, 29.9MB/s]
# 100%|##########| 612M/612M [00:19<00:00, 32.8MB/s]

# %%
from zipfile import ZipFile
# Create a ZipFile Object and load sample.zip in it
with ZipFile("gtsrb-german-traffic-sign.zip", 'r') as zipObj:
   # Extract all the contents of zip file in current directory
   zipObj.extractall()

# %%
import os
os.remove('gtsrb-german-traffic-sign.zip')

# %%
# Importing libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
import seaborn as sns
import random
from PIL import Image
from sklearn.model_selection import  train_test_split
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPool2D
# Out:
# In C:\Users\Seedevice\anaconda3\envs\pytorchenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In C:\Users\Seedevice\anaconda3\envs\pytorchenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In C:\Users\Seedevice\anaconda3\envs\pytorchenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# C:\Users\Seedevice\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\utils\validation.py:37: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LARGE_SPARSE_SUPPORTED = LooseVersion(scipy_version) >= '0.14.0'

# %%
#plot some of images to check the dataset
plt.figure(figsize=(12,12))
path = 'Test/'
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path + random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %%
# As size of images are different we have to make them equal so we will take mean of dimanesions

dim1 = []
dim2 = []

for i in range(0,43):
    labels = 'train' + '/{0}'.format(i)
    image_path = os.listdir(labels)
    for x in image_path:
        img = imread(labels +'/' + x)
        dim1.append(img.shape[0])
        dim2.append(img.shape[1])

# %%
#Printing mean dimension of images
print("Dimension 1 Mean : ",np.mean(dim1), " Dimension 2 Mean : ",np.mean(dim2))
# Out:
# Dimension 1 Mean :  50.328929582493814  Dimension 2 Mean :  50.83587951745773

# %%
# Now we will reshape the images to (50,50)
images = []
label_id = []

for i in range(43):
    labels = 'Train' + '/{0}'.format(i)
    image_path = os.listdir(labels)
    for x in image_path:
        img = Image.open(labels + '/' + x)
        img = img.resize((50,50))
        img = np.array(img)
        images.append(img)
        label_id.append(i)

# %%
#Converting images into numpy array
images = np.array(images)
#The pixel value of each image ranges between 0 and 255
#Dividing each image by 255 will scale the values between 0 and 1. This is also known as normalization.
images = images/255

# %%
label_id = np.array(label_id)
label_id.shape
# Out:
# (39209,)

# %%
images.shape
# Out:
# (39209, 50, 50, 3)

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_id).value_counts()
label_counts.head()
# Out:
# 2     2250
# 1     2220
# 13    2160
# 12    2100
# 38    2070
# dtype: int64

# %%
#Splitting the data
x_train, x_val, y_train, y_val = train_test_split(images, label_id , test_size = 0.2, random_state = 42)

# %%
#keras has a built-in function for one-hot encoding.
y_train_cat = to_categorical(y_train)
y_val_cat = to_categorical(y_val)

# %%
model = Sequential()

model.add(Conv2D(filters = 64, kernel_size = (3,3), input_shape = x_train.shape[1:], activation = 'relu', padding = 'same'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.5))

model.add(Conv2D(filters = 64, kernel_size = (3,3), activation = 'relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(43, activation = 'softmax'))

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 50, 50, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 25, 25, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 23, 23, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7744)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               991360
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                5547
# =================================================================
# Total params: 1,035,627
# Trainable params: 1,035,627
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, epochs = 10, batch_size = 128, validation_data = (x_val, y_val), verbose = 2)
# Out:
# Epoch 1/10
# 246/246 - 76s - loss: 2.4277 - accuracy: 0.3391 - val_loss: 1.0706 - val_accuracy: 0.7474
# Epoch 2/10
# 246/246 - 83s - loss: 1.0509 - accuracy: 0.6730 - val_loss: 0.3910 - val_accuracy: 0.9250
# Epoch 3/10
# 246/246 - 78s - loss: 0.6685 - accuracy: 0.7899 - val_loss: 0.2296 - val_accuracy: 0.9547
# Epoch 4/10
# 246/246 - 75s - loss: 0.5246 - accuracy: 0.8358 - val_loss: 0.1664 - val_accuracy: 0.9681
# Epoch 5/10
# 246/246 - 70s - loss: 0.4360 - accuracy: 0.8594 - val_loss: 0.1340 - val_accuracy: 0.9691
# Epoch 6/10
# 246/246 - 75s - loss: 0.3859 - accuracy: 0.8768 - val_loss: 0.1081 - val_accuracy: 0.9786
# Epoch 7/10
# 246/246 - 70s - loss: 0.3415 - accuracy: 0.8893 - val_loss: 0.0960 - val_accuracy: 0.9823
# Epoch 8/10
# 246/246 - 69s - loss: 0.3163 - accuracy: 0.8996 - val_loss: 0.0748 - val_accuracy: 0.9867
# Epoch 9/10
# 246/246 - 68s - loss: 0.2876 - accuracy: 0.9090 - val_loss: 0.0648 - val_accuracy: 0.9869
# Epoch 10/10
# 246/246 - 73s - loss: 0.2542 - accuracy: 0.9182 - val_loss: 0.0626 - val_accuracy: 0.9878

# %%
evaluation = pd.DataFrame(model.history.history)
evaluation[['accuracy', 'val_accuracy']].plot()
evaluation[['loss', 'val_loss']].plot()

# %%
test_path = 'Test'
os.remove('Test/GT-final_test.csv')

# %%
#defining a function that will scale images
from PIL import Image

def scaling(test_images, test_path):
    images = []

    image_path = test_images
    
    for x in image_path:
        img = Image.open(test_path + '/' + x)
        img = img.resize((50,50))
        img = np.array(img)
        images.append(img)

    #Converting images into numpy array
    images = np.array(images)
    #The pixel value of each image ranges between 0 and 255
    #Dividing each image by 255 will scale the values between 0 and 1. This is also known as normalization.
    images = images/255

    return images

# %%
test_images = scaling(sorted(os.listdir(test_path)),test_path)

# %%
test = pd.read_csv('Test.csv')
y_test = test['ClassId'].values
y_test
# Out:
# array([16,  1, 38, ...,  6,  7, 10], dtype=int64)

# %%
y_pred = model.predict_classes(test_images);
y_pred
# Out:
# WARNING:tensorflow:From C:\Users\Seedevice\AppData\Local\Temp\ipykernel_21724\922927862.py:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# array([16,  1, 38, ..., 32,  7, 10], dtype=int64)

# %%
# Storing all lables
all_lables = ['Speed limit (20km/h)','Speed limit (30km/h)','Speed limit (50km/h)','Speed limit (60km/h)',
              'Speed limit (70km/h)','Speed limit (80km/h)','End of speed limit (80km/h)','Speed limit (100km/h)',
              'Speed limit (120km/h)','No passing','No passing for vechiles over 3.5 metric tons',
              'Right-of-way at the next intersection','Priority road','Yield','Stop','No vechiles',
              'Vechiles over 3.5 metric tons prohibited','No entry','General caution','Dangerous curve to the left',
              'Dangerous curve to the right','Double curve','Bumpy road','Slippery road','Road narrows on the right',
              'Road work','Traffic signals','Pedestrians','Children crossing','Bicycles crossing','Beware of ice/snow',
              'Wild animals crossing','End of all speed and passing limits','Turn right ahead','Turn left ahead',
              'Ahead only','Go straight or right','Go straight or left','Keep right','Keep left','Roundabout mandatory',
              'End of no passing','End of no passing by vechiles over 3.5 metric']

# %%
# Visualize test image
img = Image.open(test_path + '/00001.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=42x45 at 0x137C4CB5908>

# %%
# Original label
print("Original label : ",all_lables[y_test[1]])
# Out:
# Original label :  Speed limit (30km/h)

# %%
# Predicted label
print("Predicted label : ",all_lables[y_pred[1]])
# Out:
# Predicted label :  Speed limit (30km/h)
